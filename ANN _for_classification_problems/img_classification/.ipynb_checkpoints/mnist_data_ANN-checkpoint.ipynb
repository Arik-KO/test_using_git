# %%
import tensorflow as tf

# %%
mnist_data = tf.keras.datasets.mnist
(x_train, y_train), (x_test,y_test) = mnist_data.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 27s 2us/step

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
model = tf.keras.models.Sequential([

tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
tf.keras.layers.Dense(10, activation='softmax'),
    
]
)

# %%
model.compile(optimizer='adam',
             loss= 'sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(x_train,y_train, 
          validation_data=(x_test, y_test),
         epochs = 10, 
         verbose = 1,
         )
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7204 - loss: 7.7302 - val_accuracy: 0.8910 - val_loss: 0.4815
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8448 - loss: 0.5943 - val_accuracy: 0.9117 - val_loss: 0.3726
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8739 - loss: 0.4823 - val_accuracy: 0.9217 - val_loss: 0.3297
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8912 - loss: 0.4097 - val_accuracy: 0.9277 - val_loss: 0.2935
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8987 - loss: 0.3870 - val_accuracy: 0.9356 - val_loss: 0.3058
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9032 - loss: 0.3696 - val_accuracy: 0.9377 - val_loss: 0.2977
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9114 - loss: 0.3403 - val_accuracy: 0.9397 - val_loss: 0.2781
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9120 - loss: 0.3300 - val_accuracy: 0.9446 - val_loss: 0.2815
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9201 - loss: 0.3116 - val_accuracy: 0.9424 - val_loss: 0.2645
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9176 - loss: 0.3171 - val_accuracy: 0.9395 - val_loss: 0.3320

# %%
import matplotlib.pyplot as plt
import pandas as pd
losses = pd.DataFrame(model.history.history)
plt.plot(losses['loss'])
plt.plot(losses['val_loss'])

# %%
losses.columns
# Out:
# Index(['accuracy', 'loss', 'val_accuracy', 'val_loss'], dtype='object')

# %%
plt.plot(losses.accuracy)
plt.plot(losses.val_accuracy)

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9315 - loss: 0.3938
# [0.33198538422584534, 0.9394999742507935]

# %%
from sklearn.metrics import confusion_matrix

# %%
import numpy as np
predictions = model.predict(x_test)
num_samples = 10  # Number of samples to visualize
plt.figure(figsize=(15, 4))

for i in range(num_samples):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_test[i], cmap='gray')
    pred_label = np.argmax(predictions[i])
    true_label = y_test[i]
    plt.title(f'Pred: {pred_label}\nTrue: {true_label}', 
              color='green' if pred_label == true_label else 'red')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
type(predictions)
# Out:
# numpy.ndarray

# %%
predictions.shape
# Out:
# (10000, 10)

# %%
plt.imshow(x_test[18], cmap='gray')

# %%
np.argmax(predictions[18])
# Out:
# np.int64(9)

# %%
y_test[18]
# Out:
# np.uint8(3)
